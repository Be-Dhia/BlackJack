# %% [markdown]
# # <p style="text-align:center">&nbsp;</p>
#
#
# <p style="text-align:center"><span style="font-size:72px"><span style="color:#f39c12"><span style="font-family:Lucida Sans Unicode, Lucida Grande, sans-serif">&nbsp;</span></span>💸<span style="color:#f39c12"><strong style="font-family:&quot;Trebuchet MS&quot;,Helvetica,sans-serif; font-weight:bold">BlackJack 🃏</strong></span></span></p>
#
# <hr />
# <p>&nbsp;</p>

# %% [markdown]
# # Milestone Project  - Blackjack Game
# In this milestone project you will be creating a Complete BlackJack Card Game in Python.
#
# Here are the requirements:
#
# * You need to create a simple text-based [BlackJack](https://en.wikipedia.org/wiki/Blackjack) game
# * The game needs to have one player versus an automated dealer.
# * The player can stand or hit.
# * The player must be able to pick their betting amount.
# * You need to keep track of the player's total money.
# * You need to alert the player of wins, losses, or busts, etc...
#
# And most importantly:
#
# * **You must use OOP and classes in some portion of your game. You can not just use functions in your game. Use classes to help you define the Deck and the Player's hand. There are many right ways to do this, so explore it well!**
#
#
# Feel free to expand this game. Try including multiple players. Try adding in Double-Down and card splits! Remember to you are free to use any resources you want and as always:
#
# # HAVE FUN!

# %% [markdown]
# # <p style="text-align:center">&nbsp;</p>
#
# <hr />
# <p style="text-align:center">&nbsp;</p>
#
# <p style="text-align:center"><span style="font-size:72px"><span style="color:#f39c12"><span style="font-family:Lucida Sans Unicode,Lucida Grande,sans-serif">&nbsp;</span></span>💻<span style="color:#f39c12"><strong>&nbsp;</strong></span><span style="color:#9b59b6"><strong><span style="font-family:Comic Sans MS,cursive">Coding Time</span></strong></span><span style="color:#f39c12"><strong>&nbsp;</strong></span>👨&zwj;💻</span></p>
#
# <p style="text-align:center">&nbsp;</p>
#
# <hr />
# <p>&nbsp;</p>

# %%
from IPython.display import clear_output
import random as rnd

# %%
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':10, 'Queen':10, 'King':10, 'Ace':11}

# %%
class Card():
    
    def __init__(self,rank,suit):
        self.suit = suit
        self.rank = rank
        self.value = values[self.rank]
    
    def __repr__(self):
        return f"{self.rank} {self.suit} {self.value}"

# %%
class Deck():
    
    def __init__(self):
        self.deck = []
        for rank in ranks :
            for suit in suits :
                self.deck.append(Card(rank,suit))
    def shuffle(self):
        rnd.shuffle(self.deck)
    
    def give_card(self):
        return self.deck.pop(0)

# %%
class Player():
    
    def __init__(self,name,isbot,balance=0):
        self.name = name
        self.__isbot = isbot
        self.__balance = balance
        self.__hand1 = []
        self.__hand2 = []
        self.__win = 0
        self.__draw = 0
        self.__lost = 0
        
    
    def __str__(self):
        return f"hello {self.name} your balance = {self.__balance}$"
    
    def give_firstc(self):
        return self.__hand1.pop(0)
    
    def takecard(self ,card , fsthand = True):
        if(fsthand):
            self.__hand1.append(card)
        else:
            self.__hand2.append(card)
    
    def showhint(self):
        som = self.__hand1[0].value
        return f"the {self.name} have {self.__hand1[0]} and another card With Point {self.__hand1[0].value}"
    
    def acesnum(self,isfhand = True):
        
        if(isfhand):
            return (len([c for c in self.__hand1 if c.value==11]))
        else:
            return (len([c for c in self.__hand1 if c.value==11]))
         
    def long(self):
        return (len(self.__hand1) , len(self.__hand2))
    
    def showcards(self,fst=True):
        h1,h2 = __class__.getSom(self)
        hcards =""
        if(fst):
            
            for cardi in self.__hand1:
                cardi
                hcards += str(cardi)+" ,"
        else:
            h1=h2
            for cardi in self.__hand2:
                cardi
                hcards += str(cardi)+" ,"
        
        return f"the {self.name} have {hcards} with total points = {h1}"
    
    def clearhand(self):
        self.__hand1 = []
        self.__hand2 = []
        
    def getcard(self):
        try:
            return (self.__hand1[0].value,self.__hand1[1].value)
        except IndexError:
            return (self.__hand1[0].value,self.__hand2[0].value)
    
    def getBal(self):
        return self.__balance
    
    def setBal(self,amount):
        self.__balance += amount
    
    def getSom(self):
        somh1=0
        for c in self.__hand1:
            somh1 += c.value
        
        somh2=0
        for c in self.__hand2:
            somh2 += c.value
        
        an = (__class__.acesnum(self,True))
        an2 = (__class__.acesnum(self,False))
        if (somh1 > 21 and an !=0):
            while(somh1 > 21 and an>=1):
                somh1 -= 10
                an -= 1
        
        if (somh2 > 21 and an2 !=0):
            while(somh2 > 21 and an2>=1):
                somh2 -= 10
                an2 -= 1
        
        return (somh1 , somh2)

# %%
class Game():
    
    def __init__(self):
        #__name = input("Please Enter Your Name : ")
        __name = "Dhia"
        __bot = Player("bot",True)
        __player = Player(__name,False,1000)
        self.__b = __bot
        self.__p = __player
        self.__bet = 0
        self.__bet2 = 0
    
    def __str__(self):
        return f"{(self.__p)} u r playing against bot"
    
    def double_bet(self):
        self.__bet *=  2
    
    def wins(self):
        self.__p.setBal(self.__bet)
    
    def lost(self,fst=True):
        if(fst):
            self.__p.setBal((self.__bet)*-1)
        else:
            self.__p.setBal((self.__bet2)*-1)
            
    def beti(self):
        while True:
            try : 
                bi = int(input(f"Enter amount to bet You have {self.__p.getBal()}$ Available: "))
            except:
                pass
            else:
                bal = self.__p.getBal()
                
                if(0 < bi <= bal):
                    self.__bet = bi
                    print(f"{self.__p.name} U placed {bi}$ ")
                    return True
                else:
                    print(f"{self.__p.name} Your balance is {bal} , You can't Place This Bet ")
                    return False
                    
    
    def Menu(self):
        c1,c2 = (self.__p.getcard())
        l1 , l2 = self.__p.long()
        if((c1 == c2) and ((self.__bet * 2) <= self.__p.getBal()) and l2==0):
            while True:
                try:
                    choix = int(input("""
                                ******************************    Menu    ************************************
                                1 - Hit : take an other Card
                                2 - Stand 
                                3 - Split 
                                4 - Surrend
                                5 - Double Down
                                """))
                    if(choix == 1):
                        return "hit"
                    elif(choix == 2):
                        return "stand"
                    elif(choix==3):
                        return "split"
                    elif(choix == 4):
                        return "surrend"
                    elif(choix == 5):
                        return "DD"
                except:
                    pass
        elif((l1 == 1 and l2 ==1) or (l1==2 and l2==1)):
            while True:
                try:
                    choix = int(input("""
                                ******************************    Menu    ************************************
                                1 - Hit : take an other Card
                                2 - Stand  
                                3 - Double Down
                                """))
                    if(choix == 1):
                        return "hit"
                    elif(choix == 2):
                        return "stand"
                    elif(choix == 3):
                        return "DD"
                except:
                    pass
        
        elif((l1)>2 or ((l2) * (l1) !=0)):
            while True:
                try:
                    choix = int(input("""
                                ******************************    Menu    ************************************
                                1 - Hit : take an other Card
                                2 - Stand  
                                """))
                    if(choix == 1):
                        return "hit"
                    elif(choix == 2):
                        return "stand"
                except:
                    pass
                
        elif((self.__bet * 2) <= self.__p.getBal()):
            while True:
                try:
                    choix = int(input("""
                                ******************************    Menu    ************************************
                                1 - Hit : take an other Card
                                2 - Stand  
                                3 - Surrend
                                4 - Double Down
                                """))
                    if(choix == 1):
                        return "hit"
                    elif(choix == 2):
                        return "stand"
                    elif(choix==3):
                        return "surrend"
                    elif(choix==4):
                        return "DD"
                except:
                    pass
       
        else:
            while True:
                try:
                    choix = int(input("""
                                ******************************    Menu    ************************************
                                1 - Hit : take an other Card
                                2 - Stand  
                                3 - Surrend
                                """))
                    if(choix == 1):
                        return "hit"
                    elif(choix == 2):
                        return "stand"
                    elif(choix==3):
                        return "surrend"
                except:
                    pass
                    
        
    
    def start(self):
        bal =self.__p.getBal()
        if( bal == 0):
            print(f"Sorry {self.__p.name} You don't have enough Money")
            return False
        deck = Deck()
        #deck.shuffle()
        self.__p.clearhand()
        self.__b.clearhand()
        print(f"Hello {self.__p.name} You have {bal}$")
        if (__class__.beti(self) == False):
            return False
        self.__b.takecard(deck.give_card())
        self.__b.takecard(deck.give_card())
        print(self.__b.showhint())
        self.__p.takecard(deck.give_card())
        self.__p.takecard(deck.give_card())
        print(self.__p.showcards())
        print(self.__p.acesnum())
        psh1, psh2 = self.__p.getSom()
        bsh1,bsh2 = self.__b.getSom()
        
        if(psh1 == 21):
            print("BLACKJAAAACK !!! You WIN")
            __class__.wins(self)
            return True
        if(bsh1 == 21):
            print("BLACKJAAAACK !!! BOT WIN")
            __class__.lost(self)
            print(self.__b.showcards())
            return True
        
        gon=True
        while gon:
            clear_output(wait=True)
            choix=(__class__.Menu(self))
            if(choix=="stand"):
                gon=False
            elif(choix=="DD"):
                __class__.double_bet(self)
                print("Taking a Card")
                self.__p.takecard(deck.give_card())
                print(self.__p.showcards())
                gon = False
                    
            elif(choix=="hit"):
                hon = True
                while(hon):
                    print("Taking a Card")
                    self.__p.takecard(deck.give_card())
                    psh1, psh2 = self.__p.getSom()
                    print(self.__p.showcards())
                    if(psh1 > 21):
                        print("You Lost")
                        __class__.lost(self)
                        return True
                    if(psh1 == 21):
                        hon=False
                        gon=False
                    clear_output(wait=True)
                    choix=(__class__.Menu(self))
                    if(choix == "stand"):
                        hon=False
                        gon=False
            elif(choix == "surrend"):
                self.__bet /= 2 
                hon=False
                gon=False
                print("You Lost")
                __class__.lost(self)
                return False
            else:
                self.__p.takecard(self.__p.give_firstc(),False)
                print(self.__p.showcards())
                print("And You Have :")
                print(self.__p.showcards(False))
                fsthand = True
                self.__bet /= 2
                self.__bet2 = self.__bet
                clear_output(wait=True)
                print("\n\n ************************* First Hand ************************** \n\n")
                print(self.__p.showcards(True))
                choix=(__class__.Menu(self))
                
                
                
                
                while(fsthand):
                    if(choix=="stand"):
                        fsthand = False
                    elif(choix=="DD"):
                        self.__bet*=2
                        print("Taking a Card")
                        self.__p.takecard(deck.give_card(),True)
                        print(self.__p.showcards(True))
                        fsthand = False

                    elif(choix=="hit"):
                        hon = True
                        while(hon):
                            print("Taking a Card")
                            self.__p.takecard(deck.give_card(),True)
                            psh1, psh2 = self.__p.getSom()
                            print(self.__p.showcards(True))
                            if(psh1 > 21):
                                print("You Lost")
                                __class__.lost(self)
                                return True
                            if(psh1 == 21):
                                hon=False
                                gon=False
                                fsthand=False
                            print(self.__p.showcards(True))
                            clear_output(wait=True)
                            print("\n\n ************************* First Hand ************************** \n\n")
                            print(self.__p.showcards(True))
                            choix=(__class__.Menu(self))
                            if(choix == "stand"):
                                hon=False
                                gon=False
                                fsthand=False
                clear_output(wait=True)               
                print("\n\n ************************* Second Hand ************************** \n\n")
                print(self.__p.showcards(False))
                choix=(__class__.Menu(self))              
                while(fsthand==False):
                    
                    if(choix=="stand"):
                        fsthand = True
                        gon=False
                    elif(choix=="DD"):
                        self.__bet2*=2
                        print("Taking a Card")
                        self.__p.takecard(deck.give_card(),False)
                        print(self.__p.showcards(False))
                        fsthand = True
                        gon=False
                    elif(choix=="hit"):
                        hon = True
                        while(hon):
                            print("Taking a Card")
                            self.__p.takecard(deck.give_card(),False)
                            psh1, psh2 = self.__p.getSom()
                            print(self.__p.showcards(False))
                            if(psh2 > 21):
                                print("You Lost")
                                __class__.lost(self,False)
                                return True
                            if(psh1 == 21):
                                hon=False
                                gon=False
                                fsthand=True
                            clear_output(wait=True)
                            print("\n\n ************************* Second Hand ************************** \n\n")
                            print(self.__p.showcards(False))
                            choix=(__class__.Menu(self))
                            if(choix == "stand"):
                                hon=False
                                gon=False
                                fsthand=True

                
            
        print("lets play")
        print(self.__b.showcards())
        psh1, psh2 = self.__p.getSom()
        bsh1,bsh2 = self.__b.getSom()
        if(psh1 > 21):
            print("You Lost")
            __class__.lost(self)
            return True
        if(psh2 > 21):
            print("You Lost")
            __class__.lost(self)
            return True
        while(bsh1 < 21 and (bsh1<psh1 or bsh1 <psh2) or (bsh1 <16) ):
            self.__b.takecard(deck.give_card())
            print("Bot Taking a Card")
            print(self.__b.showcards())
            bsh1,bsh2 = self.__b.getSom()
        print(bsh1 , psh1 ,psh2)
        
        if(bsh1>psh1 and bsh1<22):
            print("You Lost First Hand")
            __class__.lost(self)
            
        if(bsh1>psh2 and bsh1<22):
            print("You Lost Second Hand")
            __class__.lost(self)
            
        if((bsh1<psh1 and psh1<22) or (bsh1>=22 and psh1<=21)):
            print("I win First Hand")
            __class__.wins(self)
            
        if((bsh1<psh2 and psh2<22) or (bsh1>=22 and psh2<=21)):
            print("I win Second Hand")
            __class__.wins(self)
        if(bsh1 == psh1 and psh1<22):
            print("Draw First Hand")
        if(bsh1 == psh2 and psh2<22):
            print("Draw Second Hand")

# %%
g=Game()

# %%
str(g) +" hello"
# Out:
# 'hello Dhia your balance = 1000$ u r playing against bot hello'

# %%
g.start()
# Out:
#  ************************* Second Hand **************************
#
#
# the Dhia have Two Spades 2 , with total points = 2
#
#                                 ******************************    Menu    ************************************
#                                 1 - Hit : take an other Card
#                                 2 - Stand
#                                 3 - Double Down
#                                 3
# Taking a Card
# the Dhia have Two Spades 2 ,Three Diamonds 3 , with total points = 5
# lets play
# the bot have Two Hearts 2 ,Two Diamonds 2 , with total points = 4
# Bot Taking a Card
# the bot have Two Hearts 2 ,Two Diamonds 2 ,Three Spades 3 , with total points = 7
# Bot Taking a Card
# the bot have Two Hearts 2 ,Two Diamonds 2 ,Three Spades 3 ,Three Clubs 3 , with total points = 10
# Bot Taking a Card
# the bot have Two Hearts 2 ,Two Diamonds 2 ,Three Spades 3 ,Three Clubs 3 ,Four Hearts 4 , with total points = 14
# Bot Taking a Card
# ...
